# %% [markdown]
# ## Customer Segmentation using Unsupervised Machine Learning Techniques

# %% [markdown]
# Objective: Grouping customers with similar behaviour into segments and understand their preferences. The techniques used here are K-means Clustering, Hierarchical Clustering, DBSCAN Clustering

# %% [markdown]
# ### 1. Importing necessary libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline 
from mpl_toolkits import mplot3d 
import missingno as msno 
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from IPython.display import Markdown, display
from scipy.cluster.hierarchy import dendrogram, linkage 
from yellowbrick.cluster import SilhouetteVisualizer
from sklearn.metrics import silhouette_score, silhouette_samples

plt.style.use('seaborn-v0_8-darkgrid')
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2. Dataset View

# %%
data = pd.read_excel('online_retail.xlsx') 
data.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %% [markdown]
# ### 3. Dataset features and count

# %%
print("Features : ",data.columns) 
print("# of rows : ",data.shape[0]) 
print("# of columns : ",data.shape[1])
# Out:
# Features :  Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')
# # of rows :  525461
# # of columns :  8

# %% [markdown]
# ### 4. Dataset Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.1+ MB

# %% [markdown]
# ### 5. Checking for Duplicates

# %%
data.duplicated().value_counts()
# Out:
# False    518596
# True       6865
# Name: count, dtype: int64

# %% [markdown]
# `6865` duplicate values are present in the dataset

# %% [markdown]
# ### 6. Checking for Missing Values

# %%
data.isna().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      2928
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    107927
# Country             0
# dtype: int64

# %% [markdown]
# ### **Overview of observations till now**
#
# 1. Dataset has 525461 observations with 8 features
# 2. Features, `Customer ID` and `Description` has null values
# 3. There are `6865` duplicate entries in the dataset

# %% [markdown]
# ### 7. Understanding Features

# %%
data.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %% [markdown]
# 1. Invoice : Unique 6 digit number to identify a transaction. If this number starts with 'c', it means cancellation
#
# 2. StockCode : 5 digit number that identifies a product
#
# 3. Description : Product name
#
# 4. Quantity : Quantity of each product per transaction
#
# 5. InvoiceDate : Date and time at which transaction was done
#
# 6. Price : Product price per unit
#
# 7. Customer ID : 5 digit number to uniquely identify a customer
#
# 8. Country : Country where the customer is

# %% [markdown]
# ### 8. Checking unique values for each variable

# %%
for i in data.columns.tolist():
    print(f'# of unique values in {i} : {data[i].nunique()}')
# Out:
# # of unique values in Invoice : 28816
# # of unique values in StockCode : 4632
# # of unique values in Description : 4681
# # of unique values in Quantity : 825
# # of unique values in InvoiceDate : 25296
# # of unique values in Price : 1606
# # of unique values in Customer ID : 4383
# # of unique values in Country : 40

# %% [markdown]
# ### 9. Data cleaning and Feature engineering

# %% [markdown]
# #### 9.1 Dropping unnecessary columns

# %%
missing_values = (data.isna().sum()*100)/len(data) 
missing_df = pd.DataFrame({'Feature_name':data.columns,'missing_precentage':missing_values})
missing_df
# Out:
#             Feature_name  missing_precentage
# Invoice          Invoice            0.000000
# StockCode      StockCode            0.000000
# Description  Description            0.557225
# Quantity        Quantity            0.000000
# InvoiceDate  InvoiceDate            0.000000
# Price              Price            0.000000
# Customer ID  Customer ID           20.539488
# Country          Country            0.000000

# %% [markdown]
# Around 20% of observations in dataset are not assignes with any customer. These data are not valuable to form clusters. So, rows where CustomerID is a null value is dropped

# %%
data.dropna(subset=['Customer ID'], inplace=True)

# %% [markdown]
# #### 9.2 Dropping duplicate columns

# %%
data.drop_duplicates(inplace=True)

# %%
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate']) 

data['Year'] = data['InvoiceDate'].apply(lambda x:x.year) 
data['Month'] = data['InvoiceDate'].dt.month_name()
data['Day'] = data['InvoiceDate'].dt.day_name()
data['Hour'] = data['InvoiceDate'].apply(lambda x:x.hour)

# %%
data.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country  Year     Month  \
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom  2009  December
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom  2009  December
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom  2009  December
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom  2009  December
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom  2009  December
#
#        Day  Hour
# 0  Tuesday     7
# 1  Tuesday     7
# 2  Tuesday     7
# 3  Tuesday     7
# 4  Tuesday     7

# %% [markdown]
# #### 9.3 Creating Total amount feature

# %%
data['Total_amount'] = data['Quantity']*data['Price']

# %% [markdown]
# #### 9.4 Creating Time type feature

# %%
data['Time_type'] = np.where((data['Hour']>5)&(data['Hour']<18),np.where(data['Hour']<12, 'Morning', 'Afternoon'), 'Evening')

# %% [markdown]
# #### 9.5 Extracting Cancellation Data

# %%
data['Invoice'] = data['Invoice'].astype('str') 
cancel_df = data[data['Invoice'].str.contains('C')]
cancel_df.shape
# Out:
# (9816, 14)

# %% [markdown]
# #### 9.6 Dropping Cancelled data

# %%
data = data[~data['Invoice'].str.contains('C')]

# %% [markdown]
# ## 10. Exploratory Data Analysis

# %% [markdown]
# #### 10.1 Plotting highly frequent values in each column

# %%
target = ['StockCode', 'Description', 'Price', 'Customer ID',
 'Country', 'Year', 'Month', 'Day', 'Hour', 'Time_type']

# %%
data.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country', 'Year', 'Month', 'Day', 'Hour',
#        'Total_amount', 'Time_type'],
#       dtype='object')

# %%
plt.figure(figsize=(20,25), dpi=90) 
for n,col in enumerate(target):
    plt.subplot(5, 2, n+1) 
    temp = data[col].value_counts().reset_index().head(12)
    sns.barplot(x=col, y='count', data=temp).set(title=col.title())
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()

# %% [markdown]
# #### 10.2 Plotting low frequent values in each column

# %%
target2 = ['StockCode', 'Description', 'Country'] 

plt.figure(figsize=(20,7), dpi=90)
for n,col in enumerate(target2):
    plt.subplot(1, 3, n+1) 
    temp = data[col].value_counts().reset_index().tail(5)
    sns.barplot(x=col, y='count', data=temp).set(title=col.title())
    plt.xticks(rotation=45, ha='right') 
    plt.tight_layout()

# %% [markdown]
# ### Overview of observations
#
# 1. Most Customers are from United Kingdom. Considerable amount only from France, Germany, EIRE and Netherlands. Italy is javing the least number of customers
#
# 2. There are least orders placed on Saturday. Showing that maybe it is a non-working day for the retailer
#
# 3. Most of the customers purchase gifts in the month of November, October, December and September
#
# 4. Most customers wish to purchase items in afternoon and least in the evening
#
# 5. The most ordered products are WHITE HANGING HEART T-LIGHT HOLDER, REGENCY CAKESTAND 3 TIER, STRAWBERRY CERAMIC TRINKET BOX

# %% [markdown]
# #### 10.3 Visualizing Numeric Distributions

# %%
target3 = ['Quantity', 'Price', 'Total_amount']

plt.figure(figsize=(20,7), dpi=90)
for n,col in enumerate(target3):
    plt.subplot(1, 3, n+1)
    sns.distplot(data[col])
    plt.title(col.title())
    plt.xlim(0, 500) 
    plt.tight_layout()

# %% [markdown]
# The density plots exhibit positively skewed distribution because most of the values are clustered to the left

# %% [markdown]
# #### 10.4 Visualizing the distributions after log transformation of quantity

# %%
plt.figure(figsize=(20,7), dpi=90)
plt.title('Log distribution of quantity')
sns.distplot(np.log(data['Quantity'])) 
plt.show()

# %% [markdown]
# #### 10.5 Customers per country

# %%
customer_count = data.groupby('Country').nunique()['Customer ID'].reset_index().sort_values('Customer ID', ascending=False) 
customer_count.rename(columns={'Customer ID':'Customer_count'}, inplace=True)
customer_count.head()
# Out:
#            Country  Customer_count
# 34  United Kingdom            3971
# 12         Germany              67
# 11          France              47
# 28           Spain              25
# 21     Netherlands              22

# %%
plt.figure(figsize=(20,7), dpi=90) 
plt.subplot(1,2,1)
plt.xticks(rotation=45, ha='right') 
plt.title('Highest # of customers are from') 
sns.barplot(data=customer_count.head(10), x='Country', y='Customer_count')

plt.subplot(1, 2, 2)
plt.xticks(rotation=45, ha='right') 
plt.title('Least # of customers are from') 
sns.barplot(data=customer_count, x='Country', y='Customer_count')
plt.show()

# %% [markdown]
# #### 10.6 Number of cancellations countrywise

# %%
con_cancel = cancel_df.groupby('Country').count()['Invoice'].reset_index().sort_values('Invoice', ascending=False)
con_cancel.rename(columns={'Invoice': 'Cancellations'}, inplace=True)
con_cancel.head()
# Out:
#             Country  Cancellations
# 24   United Kingdom           8450
# 9           Germany            468
# 8            France            240
# 6              EIRE            202
# 3   Channel Islands             85

# %%
plt.figure(figsize=(20,7), dpi=90) 
plt.subplot(1, 2, 1) 
plt.xticks(rotation=45, ha='right') 
plt.title('Countries with highest # of cancellations')
sns.barplot(data=con_cancel.head(10), x='Country', y='Cancellations') 

plt.subplot(1, 2, 2) 
plt.xticks(rotation=45, ha='right') 
plt.title('Countries with lowest # of cancellations')
sns.barplot(data=con_cancel.tail(10), x='Country', y='Cancellations') 
plt.show()

# %% [markdown]
# ## 11. RFM Modelling

# %% [markdown]
# Adding 1 day to the Last Invoice date to set as Latest date for reference

# %%
LatestDate = data["InvoiceDate"].max() + pd.DateOffset(days=1)

# %% [markdown]
# Creating a new dataframe to calculate Recency, Frequency and Monetary scores for each customer

# %%
rfm = data.groupby('Customer ID').agg({'InvoiceDate': lambda x:(LatestDate-x.max()).days, 'Invoice': lambda x:len(x), 'Total_amount': lambda x:x.sum()})

# %% [markdown]
# Renaming Columns

# %%
rfm.rename(columns={'InvoiceDate':'Recency','Invoice':'Frequency','Total_amount':'Monetary'}, inplace=True)
rfm.reset_index().head()
# Out:
#    Customer ID  Recency  Frequency  Monetary
# 0      12346.0      165         33    372.86
# 1      12347.0        3         71   1323.32
# 2      12348.0       74         20    222.16
# 3      12349.0       43        102   2671.14
# 4      12351.0       11         21    300.93

# %% [markdown]
# Calculating RFM scores

# %%
rfm['R'] = pd.qcut(rfm['Recency'], q=4, labels=[4,3,2,1]).astype(int)
rfm['F'] = pd.qcut(rfm['Frequency'], q=4, labels=[1,2,3,4]).astype(int)
rfm['M'] = pd.qcut(rfm['Monetary'], q=4, labels=[1,2,3,4]).astype(int)

# %% [markdown]
# Finding the RFM Group for each customer by combining the factors R,Fand M

# %%
rfm['RFM'] = 100*rfm['R']+10*rfm['F']+rfm['M']

# %% [markdown]
# Finding the RFM Score for each customer by adding the factors R,Fand M

# %%
rfm['RFM_Score'] = rfm['R']+rfm['F']+rfm['M']

# %% [markdown]
# Handling the zeroes in the dataframe to avoid error in transformations

# %%
rfm.replace(0.0, 1, inplace=True)

# %% [markdown]
# Applying Log transformation on columns for smoothening the distribution

# %%
rfm['Recency_Log'] = rfm['Recency'].apply(np.log) 
rfm['Frequency_Log'] = rfm['Frequency'].apply(np.log) 
rfm['Monetary_Log'] = rfm['Monetary'].apply(np.log) 
rfm.head()
# Out:
#              Recency  Frequency  Monetary  R  F  M  RFM  RFM_Score  \
# Customer ID
# 12346.0          165         33    372.86  1  2  2  122          5
# 12347.0            3         71   1323.32  4  3  3  433         10
# 12348.0           74         20    222.16  2  2  1  221          5
# 12349.0           43        102   2671.14  3  4  4  344         11
# 12351.0           11         21    300.93  4  2  1  421          7
#
#              Recency_Log  Frequency_Log  Monetary_Log
# Customer ID
# 12346.0         5.105945       3.496508      5.921203
# 12347.0         1.098612       4.262680      7.187899
# 12348.0         4.304065       2.995732      5.403398
# 12349.0         3.761200       4.624973      7.890261
# 12351.0         2.397895       3.044522      5.706878

# %% [markdown]
# 1. A customer with RFM 444 is the best customer with good recency, frequent and spending more money
# 2. A customer with RFM 111 is a churing customer with low recency, less frequent and spending less money
# 3. A customer with RFM 144 is the customer who purchased a long time ago but used to buy frequently and spend more.

# %% [markdown]
# **Higher the RFM score, more valuable the customer is**

# %% [markdown]
# #### Visualizing RFM before and after transformations

# %%
target4 = ['Recency', 'Frequency', 'Monetary', 'Recency_Log', 'Frequency_Log', 'Monetary_Log']
plt.figure(figsize=(20,10), dpi=90)
for n,col in enumerate(target4):
    plt.subplot(2, 3, n+1)
    sns.distplot(rfm[col])
    plt.title(col.title())
    plt.tight_layout()

# %% [markdown]
# Distribution of Recency, Frequency and Monetary columns were positively skewed before transformation and approaches normal distribution after transformation. So, we will consider transformed features for further analysis

# %% [markdown]
# ## 12. Correlation Analysis

# %%
target5 = ['Recency_Log', 'Frequency_Log', 'Monetary_Log', 'RFM', 'RFM_Score'] 
plt.figure(figsize=(10,8), dpi=50) 
sns.heatmap(abs(rfm[target5].corr()), annot=True, cmap='Greens') 
plt.title('RFM Correlation heatmap')
# Out:
# Text(0.5, 1.0, 'RFM Correlation heatmap')

# %% [markdown]
# ## 13. Clustering Algorithms

# %%
X = rfm[['Recency_Log', 'Frequency_Log', 'Monetary_Log']]
X = StandardScaler().fit_transform(X)

# %%
conclusion = {} 

def del_outliers(col, overlap_supress):
    condition1 = col<col.quantile(1-overlap_supress)
    condition2 = col>col.quantile(overlap_supress)
    return col[condition1 & condition2] 

def cluster_stats(df, segment_name):

    # Storing the mean median and count of Recency, Frequency and Monetary for each group
    stats = df[["Recency","Frequency","Monetary",segment_name]].groupby(segment_name).agg(['mean','median'])
    stats['Count'] = df[segment_name].value_counts() 

    # Storing 0.25th and 0.75th Quantile of Recency, Frequency and Monetary for each group
    summary = df[["Recency","Frequency","Monetary",segment_name]].groupby(segment_name).agg({
          "Recency"   :lambda x : f'{int(x.quantile(0.25))} to {int(x.quantile(0.75))} days ago',
          "Frequency" :lambda x : f"Bought {int(x.quantile(0.25))} to {int(x.quantile(0.75))} times",
          "Monetary"  :lambda x : f"Spent around {int(x.quantile(0.25))} to {int(x.quantile(0.75))} Sterling"})
  
    # Changing the name for the columns 
    stats.columns = [f'{i}_{j}' for i, j in stats.columns]
    summary.columns=["Last_visited",'Purchase_frequency',"Money_spent"]

    return stats, summary 

# Defining a function for plotting clusters for Visualization
def plots_stats_summary(y, segment_name, er,title, overlap_supress=0.2):
    rfm[segment_name] = y 
    groups = sorted(rfm[segment_name].unique())
    stats, summary = cluster_stats(rfm, segment_name)

    plt.figure(figsize=(20,7), dpi=90)
    ax = plt.axes(projection='3d') 
    ax.set_xlabel('Recency')
    ax.set_ylabel('Frequency') 
    ax.set_zlabel('Monetary') 
    ax.set_title(title) 
    ax = ax.scatter(X[:,0], X[:,1], X[:,2], c=y, cmap='viridis') 
    plt.legend(*ax.legend_elements(), prop={'size':15}) 

    fig,ax = plt.subplots(3, figsize=(18,18), dpi=90) 

    for i in groups:
        for index,col in enumerate(['Recency', 'Frequency', 'Monetary']):
            sns.distplot(del_outliers(rfm[rfm[segment_name]==i][col], overlap_supress), ax=ax[index], kde_kws=dict(linewidth=5))
            ax[index].set_title(f'{col} Distribution')
            ax[index].legend(groups, prop={'size':15}) 
    plt.show()

    print('\n\nDisplaying the mean median and count of Recency, Frequency and Monetary for each group with the description:\n')
    display(stats.reset_index().style.background_gradient(cmap='Greens'))
    display(summary.reset_index().style.set_properties(**{'text-align': 'left'}).background_gradient(cmap=er))

    return stats, summary

# %% [markdown]
# ## A. Binning RFM_Score

# %% [markdown]
# Grouping customers based on their RFM scores into segments or bins. RFM scores help in customer segmentation as they provide insights into customer behavior and help to identify high value customers, frequant shoppers and potential churners

# %%
y = pd.qcut(rfm['RFM_Score'], q=4, labels=[1,2,3,4]).astype(int)

title = 'RFM Score Binning'
segment_name = 'Binning'
overlap_supress = 0.25
color = 'Oranges'
conclusion[segment_name] = plots_stats_summary(y, segment_name, color,title, overlap_supress)
# Out:
# Displaying the mean median and count of Recency, Frequency and Monetary for each group with the description:
# <style type="text/css">
# #T_b00c5_row0_col0, #T_b00c5_row0_col3, #T_b00c5_row0_col4, #T_b00c5_row0_col5, #T_b00c5_row0_col6, #T_b00c5_row3_col1, #T_b00c5_row3_col2, #T_b00c5_row3_col7 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_b00c5_row0_col1, #T_b00c5_row0_col2, #T_b00c5_row2_col7, #T_b00c5_row3_col0, #T_b00c5_row3_col3, #T_b00c5_row3_col4, #T_b00c5_row3_col5, #T_b00c5_row3_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_b00c5_row0_col7 {
#   background-color: #067230;
#   color: #f1f1f1;
# }
# #T_b00c5_row1_col0, #T_b00c5_row2_col6 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_b00c5_row1_col1 {
#   background-color: #90d18d;
#   color: #000000;
# }
# #T_b00c5_row1_col2 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_b00c5_row1_col3, #T_b00c5_row1_col5 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_b00c5_row1_col4, #T_b00c5_row1_col6 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_b00c5_row1_col7 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_b00c5_row2_col0 {
#   background-color: #37a055;
#   color: #f1f1f1;
# }
# #T_b00c5_row2_col1 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_b00c5_row2_col2 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_b00c5_row2_col3 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_b00c5_row2_col4 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_b00c5_row2_col5 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# </style>
# <table id="T_b00c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b00c5_level0_col0" class="col_heading level0 col0" >Binning</th>
#       <th id="T_b00c5_level0_col1" class="col_heading level0 col1" >Recency_mean</th>
#       <th id="T_b00c5_level0_col2" class="col_heading level0 col2" >Recency_median</th>
#       <th id="T_b00c5_level0_col3" class="col_heading level0 col3" >Frequency_mean</th>
#       <th id="T_b00c5_level0_col4" class="col_heading level0 col4" >Frequency_median</th>
#       <th id="T_b00c5_level0_col5" class="col_heading level0 col5" >Monetary_mean</th>
#       <th id="T_b00c5_level0_col6" class="col_heading level0 col6" >Monetary_median</th>
#       <th id="T_b00c5_level0_col7" class="col_heading level0 col7" >Count_</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b00c5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b00c5_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_b00c5_row0_col1" class="data row0 col1" >189.197240</td>
#       <td id="T_b00c5_row0_col2" class="data row0 col2" >191.000000</td>
#       <td id="T_b00c5_row0_col3" class="data row0 col3" >15.362825</td>
#       <td id="T_b00c5_row0_col4" class="data row0 col4" >13.000000</td>
#       <td id="T_b00c5_row0_col5" class="data row0 col5" >256.416633</td>
#       <td id="T_b00c5_row0_col6" class="data row0 col6" >218.125000</td>
#       <td id="T_b00c5_row0_col7" class="data row0 col7" >1232</td>
#     </tr>
#     <tr>
#       <th id="T_b00c5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b00c5_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_b00c5_row1_col1" class="data row1 col1" >88.412500</td>
#       <td id="T_b00c5_row1_col2" class="data row1 col2" >64.000000</td>
#       <td id="T_b00c5_row1_col3" class="data row1 col3" >34.152083</td>
#       <td id="T_b00c5_row1_col4" class="data row1 col4" >30.000000</td>
#       <td id="T_b00c5_row1_col5" class="data row1 col5" >709.055167</td>
#       <td id="T_b00c5_row1_col6" class="data row1 col6" >506.275000</td>
#       <td id="T_b00c5_row1_col7" class="data row1 col7" >960</td>
#     </tr>
#     <tr>
#       <th id="T_b00c5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b00c5_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_b00c5_row2_col1" class="data row2 col1" >48.867997</td>
#       <td id="T_b00c5_row2_col2" class="data row2 col2" >36.000000</td>
#       <td id="T_b00c5_row2_col3" class="data row2 col3" >89.427475</td>
#       <td id="T_b00c5_row2_col4" class="data row2 col4" >71.000000</td>
#       <td id="T_b00c5_row2_col5" class="data row2 col5" >1705.829467</td>
#       <td id="T_b00c5_row2_col6" class="data row2 col6" >1179.450000</td>
#       <td id="T_b00c5_row2_col7" class="data row2 col7" >1303</td>
#     </tr>
#     <tr>
#       <th id="T_b00c5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b00c5_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_b00c5_row3_col1" class="data row3 col1" >14.765568</td>
#       <td id="T_b00c5_row3_col2" class="data row3 col2" >11.000000</td>
#       <td id="T_b00c5_row3_col3" class="data row3 col3" >284.139194</td>
#       <td id="T_b00c5_row3_col4" class="data row3 col4" >191.000000</td>
#       <td id="T_b00c5_row3_col5" class="data row3 col5" >6811.894623</td>
#       <td id="T_b00c5_row3_col6" class="data row3 col6" >3096.140000</td>
#       <td id="T_b00c5_row3_col7" class="data row3 col7" >819</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2a15b_row0_col0 {
#   text-align: left;
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_2a15b_row0_col1, #T_2a15b_row0_col2, #T_2a15b_row0_col3, #T_2a15b_row1_col1, #T_2a15b_row1_col2, #T_2a15b_row1_col3, #T_2a15b_row2_col1, #T_2a15b_row2_col2, #T_2a15b_row2_col3, #T_2a15b_row3_col1, #T_2a15b_row3_col2, #T_2a15b_row3_col3 {
#   text-align: left;
# }
# #T_2a15b_row1_col0 {
#   text-align: left;
#   background-color: #fdb97d;
#   color: #000000;
# }
# #T_2a15b_row2_col0 {
#   text-align: left;
#   background-color: #e95e0d;
#   color: #f1f1f1;
# }
# #T_2a15b_row3_col0 {
#   text-align: left;
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2a15b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a15b_level0_col0" class="col_heading level0 col0" >Binning</th>
#       <th id="T_2a15b_level0_col1" class="col_heading level0 col1" >Last_visited</th>
#       <th id="T_2a15b_level0_col2" class="col_heading level0 col2" >Purchase_frequency</th>
#       <th id="T_2a15b_level0_col3" class="col_heading level0 col3" >Money_spent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a15b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2a15b_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_2a15b_row0_col1" class="data row0 col1" >92 to 270 days ago</td>
#       <td id="T_2a15b_row0_col2" class="data row0 col2" >Bought 7 to 21 times</td>
#       <td id="T_2a15b_row0_col3" class="data row0 col3" >Spent around 135 to 323 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_2a15b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2a15b_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_2a15b_row1_col1" class="data row1 col1" >30 to 121 days ago</td>
#       <td id="T_2a15b_row1_col2" class="data row1 col2" >Bought 20 to 43 times</td>
#       <td id="T_2a15b_row1_col3" class="data row1 col3" >Spent around 327 to 753 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_2a15b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2a15b_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_2a15b_row2_col1" class="data row2 col1" >17 to 66 days ago</td>
#       <td id="T_2a15b_row2_col2" class="data row2 col2" >Bought 49 to 102 times</td>
#       <td id="T_2a15b_row2_col3" class="data row2 col3" >Spent around 767 to 1756 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_2a15b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2a15b_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_2a15b_row3_col1" class="data row3 col1" >4 to 21 days ago</td>
#       <td id="T_2a15b_row3_col2" class="data row3 col2" >Bought 127 to 302 times</td>
#       <td id="T_2a15b_row3_col3" class="data row3 col3" >Spent around 2140 to 5263 Sterling</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## B. Quantile Based Clustering

# %% [markdown]
# Groups data points into clusters based on their distribution within quantiles.

# %%
# Splitting RFM in 4 segments based on quantiles to obtain segments
y = pd.qcut(rfm['RFM'], q=4, labels=[1,2,3,4]).astype(int)

# Plotting Segments for Visualization
title = 'RFM Quantile Based Segmentation'
segment_name = 'QuantileCut'
overlap_supress = 0.25
color='BuPu'
conclusion[segment_name] = plots_stats_summary(y, segment_name, color,title, overlap_supress)
# Out:
# Displaying the mean median and count of Recency, Frequency and Monetary for each group with the description:
# <style type="text/css">
# #T_59384_row0_col0, #T_59384_row0_col3, #T_59384_row0_col4, #T_59384_row0_col5, #T_59384_row0_col6, #T_59384_row1_col7, #T_59384_row3_col1, #T_59384_row3_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_59384_row0_col1, #T_59384_row0_col2, #T_59384_row0_col7, #T_59384_row3_col0, #T_59384_row3_col3, #T_59384_row3_col4, #T_59384_row3_col5, #T_59384_row3_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_59384_row1_col0 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_59384_row1_col1 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_59384_row1_col2, #T_59384_row1_col6 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_59384_row1_col3 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_59384_row1_col4 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_59384_row1_col5 {
#   background-color: #dcf2d7;
#   color: #000000;
# }
# #T_59384_row2_col0 {
#   background-color: #37a055;
#   color: #f1f1f1;
# }
# #T_59384_row2_col1 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_59384_row2_col2 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_59384_row2_col3, #T_59384_row2_col6 {
#   background-color: #8bcf89;
#   color: #000000;
# }
# #T_59384_row2_col4 {
#   background-color: #83cb82;
#   color: #000000;
# }
# #T_59384_row2_col5 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_59384_row2_col7 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_59384_row3_col7 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# </style>
# <table id="T_59384">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59384_level0_col0" class="col_heading level0 col0" >QuantileCut</th>
#       <th id="T_59384_level0_col1" class="col_heading level0 col1" >Recency_mean</th>
#       <th id="T_59384_level0_col2" class="col_heading level0 col2" >Recency_median</th>
#       <th id="T_59384_level0_col3" class="col_heading level0 col3" >Frequency_mean</th>
#       <th id="T_59384_level0_col4" class="col_heading level0 col4" >Frequency_median</th>
#       <th id="T_59384_level0_col5" class="col_heading level0 col5" >Monetary_mean</th>
#       <th id="T_59384_level0_col6" class="col_heading level0 col6" >Monetary_median</th>
#       <th id="T_59384_level0_col7" class="col_heading level0 col7" >Count_</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59384_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_59384_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_59384_row0_col1" class="data row0 col1" >218.884984</td>
#       <td id="T_59384_row0_col2" class="data row0 col2" >216.000000</td>
#       <td id="T_59384_row0_col3" class="data row0 col3" >28.066294</td>
#       <td id="T_59384_row0_col4" class="data row0 col4" >17.000000</td>
#       <td id="T_59384_row0_col5" class="data row0 col5" >572.412016</td>
#       <td id="T_59384_row0_col6" class="data row0 col6" >270.985000</td>
#       <td id="T_59384_row0_col7" class="data row0 col7" >1252</td>
#     </tr>
#     <tr>
#       <th id="T_59384_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_59384_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_59384_row1_col1" class="data row1 col1" >76.865597</td>
#       <td id="T_59384_row1_col2" class="data row1 col2" >73.000000</td>
#       <td id="T_59384_row1_col3" class="data row1 col3" >64.334002</td>
#       <td id="T_59384_row1_col4" class="data row1 col4" >41.000000</td>
#       <td id="T_59384_row1_col5" class="data row1 col5" >1269.541877</td>
#       <td id="T_59384_row1_col6" class="data row1 col6" >717.570000</td>
#       <td id="T_59384_row1_col7" class="data row1 col7" >997</td>
#     </tr>
#     <tr>
#       <th id="T_59384_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_59384_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_59384_row2_col1" class="data row2 col1" >32.590953</td>
#       <td id="T_59384_row2_col2" class="data row2 col2" >31.000000</td>
#       <td id="T_59384_row2_col3" class="data row2 col3" >99.823869</td>
#       <td id="T_59384_row2_col4" class="data row2 col4" >57.000000</td>
#       <td id="T_59384_row2_col5" class="data row2 col5" >1702.253528</td>
#       <td id="T_59384_row2_col6" class="data row2 col6" >895.760000</td>
#       <td id="T_59384_row2_col7" class="data row2 col7" >1039</td>
#     </tr>
#     <tr>
#       <th id="T_59384_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_59384_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_59384_row3_col1" class="data row3 col1" >8.961014</td>
#       <td id="T_59384_row3_col2" class="data row3 col2" >9.000000</td>
#       <td id="T_59384_row3_col3" class="data row3 col3" >192.933723</td>
#       <td id="T_59384_row3_col4" class="data row3 col4" >104.500000</td>
#       <td id="T_59384_row3_col5" class="data row3 col5" >4919.299447</td>
#       <td id="T_59384_row3_col6" class="data row3 col6" >1700.695000</td>
#       <td id="T_59384_row3_col7" class="data row3 col7" >1026</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_15a7a_row0_col0 {
#   text-align: left;
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_15a7a_row0_col1, #T_15a7a_row0_col2, #T_15a7a_row0_col3, #T_15a7a_row1_col1, #T_15a7a_row1_col2, #T_15a7a_row1_col3, #T_15a7a_row2_col1, #T_15a7a_row2_col2, #T_15a7a_row2_col3, #T_15a7a_row3_col1, #T_15a7a_row3_col2, #T_15a7a_row3_col3 {
#   text-align: left;
# }
# #T_15a7a_row1_col0 {
#   text-align: left;
#   background-color: #a9c4de;
#   color: #000000;
# }
# #T_15a7a_row2_col0 {
#   text-align: left;
#   background-color: #8b5daa;
#   color: #f1f1f1;
# }
# #T_15a7a_row3_col0 {
#   text-align: left;
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_15a7a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15a7a_level0_col0" class="col_heading level0 col0" >QuantileCut</th>
#       <th id="T_15a7a_level0_col1" class="col_heading level0 col1" >Last_visited</th>
#       <th id="T_15a7a_level0_col2" class="col_heading level0 col2" >Purchase_frequency</th>
#       <th id="T_15a7a_level0_col3" class="col_heading level0 col3" >Money_spent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15a7a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_15a7a_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_15a7a_row0_col1" class="data row0 col1" >163 to 278 days ago</td>
#       <td id="T_15a7a_row0_col2" class="data row0 col2" >Bought 8 to 35 times</td>
#       <td id="T_15a7a_row0_col3" class="data row0 col3" >Spent around 151 to 535 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_15a7a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_15a7a_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_15a7a_row1_col1" class="data row1 col1" >59 to 95 days ago</td>
#       <td id="T_15a7a_row1_col2" class="data row1 col2" >Bought 20 to 77 times</td>
#       <td id="T_15a7a_row1_col3" class="data row1 col3" >Spent around 352 to 1471 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_15a7a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_15a7a_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_15a7a_row2_col1" class="data row2 col1" >24 to 42 days ago</td>
#       <td id="T_15a7a_row2_col2" class="data row2 col2" >Bought 27 to 124 times</td>
#       <td id="T_15a7a_row2_col3" class="data row2 col3" >Spent around 442 to 2038 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_15a7a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_15a7a_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_15a7a_row3_col1" class="data row3 col1" >4 to 14 days ago</td>
#       <td id="T_15a7a_row3_col2" class="data row3 col2" >Bought 54 to 211 times</td>
#       <td id="T_15a7a_row3_col3" class="data row3 col3" >Spent around 816 to 3783 Sterling</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## C. K-Means Clustering

# %% [markdown]
# K-means clustering is a popular unsupervised machine learning algorithm used for clustering data points based on their similarity. It divides the data set into K clusters, where K is a predefined number

# %%
# Storing sum of squared distances and Silhouette Scores for each value of k in k means clusterer
ssd,score = [],[]
# Setting figure Size
plt.figure(figsize=(20,5), dpi=90)

# Initializing the list of clusters for tuning the best clusters
n_clusters = list(range(2,16))

# Running a for loop of Kmeans algorithm
for k in n_clusters:
    clusterer = KMeans(n_clusters = k, init= 'k-means++', max_iter= 1000)
    y_preds = clusterer.fit_predict(X)                                          
    ssd.append(clusterer.inertia_)                                              
    score.append(silhouette_score(X, y_preds))                                  

# Plotting Elbow curve to find optimal K
plt.subplot(1, 2, 1)                                                            
sns.pointplot(x=n_clusters, y=ssd)                                              
plt.xlabel('Number of Clusters(k)')                                             
plt.ylabel('Sum of Squared Distances')                                          
plt.title('Elbow Curve')                                                        

# Silhouette Score v/s Number of Clusters
plt.subplot(1, 2, 2)                                                            
sns.barplot(x=n_clusters, y=score)                                              
plt.xlabel('Number of Clusters(k)')                                             
plt.ylabel('Silhouette Score')                                                  
plt.title('Silhouette Scores')                                                  
plt.tight_layout()

# %%
# Visualizing the Silouette plots for the clusters
for i in range(2,7):
    plt.figure(figsize = (8, 3), dpi=150)
    kmeans=KMeans(i,init="k-means++")
    visualizer=SilhouetteVisualizer(kmeans,colors='yellowbrick')
    visualizer.fit(X)
    visualizer.show()

# %%
# Fitting the model on n_clusters = 2 based on Silhouette_Score to visualise the segments.
kmc = KMeans(n_clusters=2,init="k-means++")          
y = kmc.fit_predict(X)                                  
centers = kmc.cluster_centers_                          

# Plotting Clusters for Visualization
title = 'K-Means Clustering based on Silhouette_Score' 
segment_name = 'K-Means|2Cluster'
overlap_supress = 0.1
color="inferno"
conclusion[segment_name] = plots_stats_summary(y, segment_name, color,title, overlap_supress)
# Out:
# Displaying the mean median and count of Recency, Frequency and Monetary for each group with the description:
# <style type="text/css">
# #T_4e97c_row0_col0, #T_4e97c_row0_col1, #T_4e97c_row0_col2, #T_4e97c_row0_col7, #T_4e97c_row1_col3, #T_4e97c_row1_col4, #T_4e97c_row1_col5, #T_4e97c_row1_col6 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_4e97c_row0_col3, #T_4e97c_row0_col4, #T_4e97c_row0_col5, #T_4e97c_row0_col6, #T_4e97c_row1_col0, #T_4e97c_row1_col1, #T_4e97c_row1_col2, #T_4e97c_row1_col7 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4e97c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e97c_level0_col0" class="col_heading level0 col0" >K-Means|2Cluster</th>
#       <th id="T_4e97c_level0_col1" class="col_heading level0 col1" >Recency_mean</th>
#       <th id="T_4e97c_level0_col2" class="col_heading level0 col2" >Recency_median</th>
#       <th id="T_4e97c_level0_col3" class="col_heading level0 col3" >Frequency_mean</th>
#       <th id="T_4e97c_level0_col4" class="col_heading level0 col4" >Frequency_median</th>
#       <th id="T_4e97c_level0_col5" class="col_heading level0 col5" >Monetary_mean</th>
#       <th id="T_4e97c_level0_col6" class="col_heading level0 col6" >Monetary_median</th>
#       <th id="T_4e97c_level0_col7" class="col_heading level0 col7" >Count_</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e97c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e97c_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_4e97c_row0_col1" class="data row0 col1" >35.744888</td>
#       <td id="T_4e97c_row0_col2" class="data row0 col2" >21.000000</td>
#       <td id="T_4e97c_row0_col3" class="data row0 col3" >168.984907</td>
#       <td id="T_4e97c_row0_col4" class="data row0 col4" >104.000000</td>
#       <td id="T_4e97c_row0_col5" class="data row0 col5" >3799.774144</td>
#       <td id="T_4e97c_row0_col6" class="data row0 col6" >1753.065000</td>
#       <td id="T_4e97c_row0_col7" class="data row0 col7" >2054</td>
#     </tr>
#     <tr>
#       <th id="T_4e97c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4e97c_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_4e97c_row1_col1" class="data row1 col1" >141.732301</td>
#       <td id="T_4e97c_row1_col2" class="data row1 col2" >112.000000</td>
#       <td id="T_4e97c_row1_col3" class="data row1 col3" >23.828319</td>
#       <td id="T_4e97c_row1_col4" class="data row1 col4" >19.000000</td>
#       <td id="T_4e97c_row1_col5" class="data row1 col5" >439.601616</td>
#       <td id="T_4e97c_row1_col6" class="data row1 col6" >318.495000</td>
#       <td id="T_4e97c_row1_col7" class="data row1 col7" >2260</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_18cea_row0_col0 {
#   text-align: left;
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_18cea_row0_col1, #T_18cea_row0_col2, #T_18cea_row0_col3, #T_18cea_row1_col1, #T_18cea_row1_col2, #T_18cea_row1_col3 {
#   text-align: left;
# }
# #T_18cea_row1_col0 {
#   text-align: left;
#   background-color: #fcffa4;
#   color: #000000;
# }
# </style>
# <table id="T_18cea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18cea_level0_col0" class="col_heading level0 col0" >K-Means|2Cluster</th>
#       <th id="T_18cea_level0_col1" class="col_heading level0 col1" >Last_visited</th>
#       <th id="T_18cea_level0_col2" class="col_heading level0 col2" >Purchase_frequency</th>
#       <th id="T_18cea_level0_col3" class="col_heading level0 col3" >Money_spent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18cea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18cea_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_18cea_row0_col1" class="data row0 col1" >9 to 49 days ago</td>
#       <td id="T_18cea_row0_col2" class="data row0 col2" >Bought 66 to 188 times</td>
#       <td id="T_18cea_row0_col3" class="data row0 col3" >Spent around 1036 to 3198 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_18cea_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_18cea_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_18cea_row1_col1" class="data row1 col1" >52 to 226 days ago</td>
#       <td id="T_18cea_row1_col2" class="data row1 col2" >Bought 10 to 34 times</td>
#       <td id="T_18cea_row1_col3" class="data row1 col3" >Spent around 181 to 541 Sterling</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Fitting the model on n_clusters = 5 based on Elbow_Curve to visualise the segments.
kmc = KMeans(n_clusters=5,init="k-means++")           
y = kmc.fit_predict(X)                                
centers = kmc.cluster_centers_                        

# Plotting Clusters for Visualization
title = 'K-Means Clustering based on Elbow_Curve'     
segment_name = 'K-Means|5Cluster'
overlap_supress = 0.2
color="tab20"
conclusion[segment_name] = plots_stats_summary(y, segment_name,color, title, overlap_supress)
# Out:
# Displaying the mean median and count of Recency, Frequency and Monetary for each group with the description:
# <style type="text/css">
# #T_3001b_row0_col0, #T_3001b_row0_col7, #T_3001b_row1_col3, #T_3001b_row1_col4, #T_3001b_row1_col5, #T_3001b_row1_col6, #T_3001b_row2_col1, #T_3001b_row2_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_3001b_row0_col1, #T_3001b_row3_col6 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_3001b_row0_col2 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_3001b_row0_col3, #T_3001b_row0_col4, #T_3001b_row0_col5, #T_3001b_row0_col6, #T_3001b_row1_col1, #T_3001b_row1_col2, #T_3001b_row4_col0, #T_3001b_row4_col7 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_3001b_row1_col0 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_3001b_row1_col7 {
#   background-color: #3ba458;
#   color: #f1f1f1;
# }
# #T_3001b_row2_col0 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_3001b_row2_col3 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_3001b_row2_col4 {
#   background-color: #bce4b5;
#   color: #000000;
# }
# #T_3001b_row2_col5 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_3001b_row2_col6 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_3001b_row2_col7 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_3001b_row3_col0 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_3001b_row3_col1 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_3001b_row3_col2 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_3001b_row3_col3 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_3001b_row3_col4 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_3001b_row3_col5 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_3001b_row3_col7 {
#   background-color: #83cb82;
#   color: #000000;
# }
# #T_3001b_row4_col1 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_3001b_row4_col2 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_3001b_row4_col3 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_3001b_row4_col4 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_3001b_row4_col5 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_3001b_row4_col6 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# </style>
# <table id="T_3001b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3001b_level0_col0" class="col_heading level0 col0" >K-Means|5Cluster</th>
#       <th id="T_3001b_level0_col1" class="col_heading level0 col1" >Recency_mean</th>
#       <th id="T_3001b_level0_col2" class="col_heading level0 col2" >Recency_median</th>
#       <th id="T_3001b_level0_col3" class="col_heading level0 col3" >Frequency_mean</th>
#       <th id="T_3001b_level0_col4" class="col_heading level0 col4" >Frequency_median</th>
#       <th id="T_3001b_level0_col5" class="col_heading level0 col5" >Monetary_mean</th>
#       <th id="T_3001b_level0_col6" class="col_heading level0 col6" >Monetary_median</th>
#       <th id="T_3001b_level0_col7" class="col_heading level0 col7" >Count_</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3001b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3001b_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_3001b_row0_col1" class="data row0 col1" >17.691429</td>
#       <td id="T_3001b_row0_col2" class="data row0 col2" >12.000000</td>
#       <td id="T_3001b_row0_col3" class="data row0 col3" >375.908571</td>
#       <td id="T_3001b_row0_col4" class="data row0 col4" >264.000000</td>
#       <td id="T_3001b_row0_col5" class="data row0 col5" >10057.810926</td>
#       <td id="T_3001b_row0_col6" class="data row0 col6" >4834.400000</td>
#       <td id="T_3001b_row0_col7" class="data row0 col7" >525</td>
#     </tr>
#     <tr>
#       <th id="T_3001b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3001b_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_3001b_row1_col1" class="data row1 col1" >213.826827</td>
#       <td id="T_3001b_row1_col2" class="data row1 col2" >215.000000</td>
#       <td id="T_3001b_row1_col3" class="data row1 col3" >14.376376</td>
#       <td id="T_3001b_row1_col4" class="data row1 col4" >12.000000</td>
#       <td id="T_3001b_row1_col5" class="data row1 col5" >259.649250</td>
#       <td id="T_3001b_row1_col6" class="data row1 col6" >203.140000</td>
#       <td id="T_3001b_row1_col7" class="data row1 col7" >999</td>
#     </tr>
#     <tr>
#       <th id="T_3001b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3001b_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_3001b_row2_col1" class="data row2 col1" >10.884615</td>
#       <td id="T_3001b_row2_col2" class="data row2 col2" >10.000000</td>
#       <td id="T_3001b_row2_col3" class="data row2 col3" >96.804734</td>
#       <td id="T_3001b_row2_col4" class="data row2 col4" >84.500000</td>
#       <td id="T_3001b_row2_col5" class="data row2 col5" >1432.830476</td>
#       <td id="T_3001b_row2_col6" class="data row2 col6" >1278.130000</td>
#       <td id="T_3001b_row2_col7" class="data row2 col7" >676</td>
#     </tr>
#     <tr>
#       <th id="T_3001b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3001b_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_3001b_row3_col1" class="data row3 col1" >39.933721</td>
#       <td id="T_3001b_row3_col2" class="data row3 col2" >36.000000</td>
#       <td id="T_3001b_row3_col3" class="data row3 col3" >23.315116</td>
#       <td id="T_3001b_row3_col4" class="data row3 col4" >21.000000</td>
#       <td id="T_3001b_row3_col5" class="data row3 col5" >425.409209</td>
#       <td id="T_3001b_row3_col6" class="data row3 col6" >350.435000</td>
#       <td id="T_3001b_row3_col7" class="data row3 col7" >860</td>
#     </tr>
#     <tr>
#       <th id="T_3001b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3001b_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_3001b_row4_col1" class="data row4 col1" >102.976874</td>
#       <td id="T_3001b_row4_col2" class="data row4 col2" >75.000000</td>
#       <td id="T_3001b_row4_col3" class="data row4 col3" >82.728868</td>
#       <td id="T_3001b_row4_col4" class="data row4 col4" >67.000000</td>
#       <td id="T_3001b_row4_col5" class="data row4 col5" >1534.330211</td>
#       <td id="T_3001b_row4_col6" class="data row4 col6" >1128.830000</td>
#       <td id="T_3001b_row4_col7" class="data row4 col7" >1254</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_111ad_row0_col0 {
#   text-align: left;
#   background-color: #1f77b4;
#   color: #f1f1f1;
# }
# #T_111ad_row0_col1, #T_111ad_row0_col2, #T_111ad_row0_col3, #T_111ad_row1_col1, #T_111ad_row1_col2, #T_111ad_row1_col3, #T_111ad_row2_col1, #T_111ad_row2_col2, #T_111ad_row2_col3, #T_111ad_row3_col1, #T_111ad_row3_col2, #T_111ad_row3_col3, #T_111ad_row4_col1, #T_111ad_row4_col2, #T_111ad_row4_col3 {
#   text-align: left;
# }
# #T_111ad_row1_col0 {
#   text-align: left;
#   background-color: #98df8a;
#   color: #000000;
# }
# #T_111ad_row2_col0 {
#   text-align: left;
#   background-color: #8c564b;
#   color: #f1f1f1;
# }
# #T_111ad_row3_col0 {
#   text-align: left;
#   background-color: #c7c7c7;
#   color: #000000;
# }
# #T_111ad_row4_col0 {
#   text-align: left;
#   background-color: #9edae5;
#   color: #000000;
# }
# </style>
# <table id="T_111ad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_111ad_level0_col0" class="col_heading level0 col0" >K-Means|5Cluster</th>
#       <th id="T_111ad_level0_col1" class="col_heading level0 col1" >Last_visited</th>
#       <th id="T_111ad_level0_col2" class="col_heading level0 col2" >Purchase_frequency</th>
#       <th id="T_111ad_level0_col3" class="col_heading level0 col3" >Money_spent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_111ad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_111ad_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_111ad_row0_col1" class="data row0 col1" >5 to 24 days ago</td>
#       <td id="T_111ad_row0_col2" class="data row0 col2" >Bought 180 to 415 times</td>
#       <td id="T_111ad_row0_col3" class="data row0 col3" >Spent around 3318 to 8018 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_111ad_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_111ad_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_111ad_row1_col1" class="data row1 col1" >141 to 286 days ago</td>
#       <td id="T_111ad_row1_col2" class="data row1 col2" >Bought 6 to 20 times</td>
#       <td id="T_111ad_row1_col3" class="data row1 col3" >Spent around 127 to 319 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_111ad_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_111ad_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_111ad_row2_col1" class="data row2 col1" >4 to 16 days ago</td>
#       <td id="T_111ad_row2_col2" class="data row2 col2" >Bought 57 to 123 times</td>
#       <td id="T_111ad_row2_col3" class="data row2 col3" >Spent around 818 to 1854 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_111ad_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_111ad_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_111ad_row3_col1" class="data row3 col1" >21 to 56 days ago</td>
#       <td id="T_111ad_row3_col2" class="data row3 col2" >Bought 13 to 30 times</td>
#       <td id="T_111ad_row3_col3" class="data row3 col3" >Spent around 237 to 503 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_111ad_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_111ad_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_111ad_row4_col1" class="data row4 col1" >51 to 137 days ago</td>
#       <td id="T_111ad_row4_col2" class="data row4 col2" >Bought 44 to 103 times</td>
#       <td id="T_111ad_row4_col3" class="data row4 col3" >Spent around 733 to 1825 Sterling</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Fitting the model on n_clusters = 4 based on Both Elbow_Curve & Silhouette_Score to visualise the segments.
kmc = KMeans(n_clusters=4,init="k-means++")         
y = kmc.fit_predict(X)                              
centers = kmc.cluster_centers_                      

# Plotting Clusters for Visualization
title = 'K-Means Clustering based on Both Elbow_Curve & Silhouette_Score'         
segment_name = 'K-Means|4Cluster'
overlap_supress = 0.2
color="Pastel1"
conclusion[segment_name] = plots_stats_summary(y, segment_name, color,title, overlap_supress)
# Out:
# Displaying the mean median and count of Recency, Frequency and Monetary for each group with the description:
# <style type="text/css">
# #T_b91fe_row0_col0, #T_b91fe_row0_col3, #T_b91fe_row0_col4, #T_b91fe_row0_col5, #T_b91fe_row0_col6, #T_b91fe_row3_col1, #T_b91fe_row3_col2, #T_b91fe_row3_col7 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_b91fe_row0_col1, #T_b91fe_row0_col2, #T_b91fe_row2_col7, #T_b91fe_row3_col0, #T_b91fe_row3_col3, #T_b91fe_row3_col4, #T_b91fe_row3_col5, #T_b91fe_row3_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_b91fe_row0_col7 {
#   background-color: #0c7735;
#   color: #f1f1f1;
# }
# #T_b91fe_row1_col0 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_b91fe_row1_col1 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_b91fe_row1_col2 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_b91fe_row1_col3 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_b91fe_row1_col4 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_b91fe_row1_col5 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_b91fe_row1_col6 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_b91fe_row1_col7 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_b91fe_row2_col0 {
#   background-color: #37a055;
#   color: #f1f1f1;
# }
# #T_b91fe_row2_col1 {
#   background-color: #6dc072;
#   color: #000000;
# }
# #T_b91fe_row2_col2 {
#   background-color: #9ed798;
#   color: #000000;
# }
# #T_b91fe_row2_col3 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_b91fe_row2_col4 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_b91fe_row2_col5 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_b91fe_row2_col6 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# </style>
# <table id="T_b91fe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b91fe_level0_col0" class="col_heading level0 col0" >K-Means|4Cluster</th>
#       <th id="T_b91fe_level0_col1" class="col_heading level0 col1" >Recency_mean</th>
#       <th id="T_b91fe_level0_col2" class="col_heading level0 col2" >Recency_median</th>
#       <th id="T_b91fe_level0_col3" class="col_heading level0 col3" >Frequency_mean</th>
#       <th id="T_b91fe_level0_col4" class="col_heading level0 col4" >Frequency_median</th>
#       <th id="T_b91fe_level0_col5" class="col_heading level0 col5" >Monetary_mean</th>
#       <th id="T_b91fe_level0_col6" class="col_heading level0 col6" >Monetary_median</th>
#       <th id="T_b91fe_level0_col7" class="col_heading level0 col7" >Count_</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b91fe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b91fe_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_b91fe_row0_col1" class="data row0 col1" >186.177723</td>
#       <td id="T_b91fe_row0_col2" class="data row0 col2" >185.000000</td>
#       <td id="T_b91fe_row0_col3" class="data row0 col3" >14.597871</td>
#       <td id="T_b91fe_row0_col4" class="data row0 col4" >13.000000</td>
#       <td id="T_b91fe_row0_col5" class="data row0 col5" >270.073170</td>
#       <td id="T_b91fe_row0_col6" class="data row0 col6" >216.400000</td>
#       <td id="T_b91fe_row0_col7" class="data row0 col7" >1221</td>
#     </tr>
#     <tr>
#       <th id="T_b91fe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b91fe_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_b91fe_row1_col1" class="data row1 col1" >23.474261</td>
#       <td id="T_b91fe_row1_col2" class="data row1 col2" >21.000000</td>
#       <td id="T_b91fe_row1_col3" class="data row1 col3" >37.473165</td>
#       <td id="T_b91fe_row1_col4" class="data row1 col4" >31.000000</td>
#       <td id="T_b91fe_row1_col5" class="data row1 col5" >590.904547</td>
#       <td id="T_b91fe_row1_col6" class="data row1 col6" >485.860000</td>
#       <td id="T_b91fe_row1_col7" class="data row1 col7" >913</td>
#     </tr>
#     <tr>
#       <th id="T_b91fe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b91fe_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_b91fe_row2_col1" class="data row2 col1" >102.878882</td>
#       <td id="T_b91fe_row2_col2" class="data row2 col2" >77.000000</td>
#       <td id="T_b91fe_row2_col3" class="data row2 col3" >81.520186</td>
#       <td id="T_b91fe_row2_col4" class="data row2 col4" >66.000000</td>
#       <td id="T_b91fe_row2_col5" class="data row2 col5" >1557.086595</td>
#       <td id="T_b91fe_row2_col6" class="data row2 col6" >1121.345000</td>
#       <td id="T_b91fe_row2_col7" class="data row2 col7" >1288</td>
#     </tr>
#     <tr>
#       <th id="T_b91fe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b91fe_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_b91fe_row3_col1" class="data row3 col1" >13.982063</td>
#       <td id="T_b91fe_row3_col2" class="data row3 col2" >10.000000</td>
#       <td id="T_b91fe_row3_col3" class="data row3 col3" >273.443946</td>
#       <td id="T_b91fe_row3_col4" class="data row3 col4" >185.500000</td>
#       <td id="T_b91fe_row3_col5" class="data row3 col5" >6640.642397</td>
#       <td id="T_b91fe_row3_col6" class="data row3 col6" >3004.930000</td>
#       <td id="T_b91fe_row3_col7" class="data row3 col7" >892</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f6734_row0_col0 {
#   text-align: left;
#   background-color: #fbb4ae;
#   color: #000000;
# }
# #T_f6734_row0_col1, #T_f6734_row0_col2, #T_f6734_row0_col3, #T_f6734_row1_col1, #T_f6734_row1_col2, #T_f6734_row1_col3, #T_f6734_row2_col1, #T_f6734_row2_col2, #T_f6734_row2_col3, #T_f6734_row3_col1, #T_f6734_row3_col2, #T_f6734_row3_col3 {
#   text-align: left;
# }
# #T_f6734_row1_col0 {
#   text-align: left;
#   background-color: #decbe4;
#   color: #000000;
# }
# #T_f6734_row2_col0 {
#   text-align: left;
#   background-color: #e5d8bd;
#   color: #000000;
# }
# #T_f6734_row3_col0 {
#   text-align: left;
#   background-color: #f2f2f2;
#   color: #000000;
# }
# </style>
# <table id="T_f6734">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6734_level0_col0" class="col_heading level0 col0" >K-Means|4Cluster</th>
#       <th id="T_f6734_level0_col1" class="col_heading level0 col1" >Last_visited</th>
#       <th id="T_f6734_level0_col2" class="col_heading level0 col2" >Purchase_frequency</th>
#       <th id="T_f6734_level0_col3" class="col_heading level0 col3" >Money_spent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6734_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f6734_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_f6734_row0_col1" class="data row0 col1" >87 to 268 days ago</td>
#       <td id="T_f6734_row0_col2" class="data row0 col2" >Bought 6 to 20 times</td>
#       <td id="T_f6734_row0_col3" class="data row0 col3" >Spent around 134 to 324 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_f6734_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f6734_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_f6734_row1_col1" class="data row1 col1" >12 to 32 days ago</td>
#       <td id="T_f6734_row1_col2" class="data row1 col2" >Bought 19 to 51 times</td>
#       <td id="T_f6734_row1_col3" class="data row1 col3" >Spent around 313 to 754 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_f6734_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f6734_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_f6734_row2_col1" class="data row2 col1" >53 to 135 days ago</td>
#       <td id="T_f6734_row2_col2" class="data row2 col2" >Bought 42 to 102 times</td>
#       <td id="T_f6734_row2_col3" class="data row2 col3" >Spent around 712 to 1795 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_f6734_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f6734_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_f6734_row3_col1" class="data row3 col1" >4 to 19 days ago</td>
#       <td id="T_f6734_row3_col2" class="data row3 col2" >Bought 115 to 295 times</td>
#       <td id="T_f6734_row3_col3" class="data row3 col3" >Spent around 1904 to 5404 Sterling</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## D. Hierarchical Clustering

# %%
# Using the Dendogram to Decide the number of clusters
plt.figure(figsize=(20,12), dpi=90)                         
dendrogram(linkage(X, method='ward'), color_threshold=50)   # using ward linkage method to differ similarities
plt.title('Dendrogram')                                     
plt.xlabel('Customers')                                     
plt.ylabel('Euclidean Distances')                           
plt.axhline(y=50, color='black', linestyle='--')            
plt.axhline(y=45, color='black', linestyle='--')           
plt.show()

# %% [markdown]
# Larget threshold, y = 50, gives 2 clusters while smaller, y = 45, gives 3 clusters

# %%
# Fitting hierarchical clustering with number of clusters based on dendogram distance threshold = 70
ahc = AgglomerativeClustering(n_clusters=2, linkage='ward')     # Initializing the model
y = ahc.fit_predict(X)                                                               

# Visualizing the clusters with n_clusters = 2
title = 'Agglomerative Clustering (threshold=50)'                                     
segment_name = 'hierarchical|2Cluster'
overlap_supress = 0.1
color="gnuplot"
conclusion[segment_name] = plots_stats_summary(y, segment_name, color,title, overlap_supress)
# Out:
# Displaying the mean median and count of Recency, Frequency and Monetary for each group with the description:
# <style type="text/css">
# #T_6e78d_row0_col0, #T_6e78d_row0_col1, #T_6e78d_row0_col2, #T_6e78d_row1_col3, #T_6e78d_row1_col4, #T_6e78d_row1_col5, #T_6e78d_row1_col6, #T_6e78d_row1_col7 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_6e78d_row0_col3, #T_6e78d_row0_col4, #T_6e78d_row0_col5, #T_6e78d_row0_col6, #T_6e78d_row0_col7, #T_6e78d_row1_col0, #T_6e78d_row1_col1, #T_6e78d_row1_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6e78d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e78d_level0_col0" class="col_heading level0 col0" >hierarchical|2Cluster</th>
#       <th id="T_6e78d_level0_col1" class="col_heading level0 col1" >Recency_mean</th>
#       <th id="T_6e78d_level0_col2" class="col_heading level0 col2" >Recency_median</th>
#       <th id="T_6e78d_level0_col3" class="col_heading level0 col3" >Frequency_mean</th>
#       <th id="T_6e78d_level0_col4" class="col_heading level0 col4" >Frequency_median</th>
#       <th id="T_6e78d_level0_col5" class="col_heading level0 col5" >Monetary_mean</th>
#       <th id="T_6e78d_level0_col6" class="col_heading level0 col6" >Monetary_median</th>
#       <th id="T_6e78d_level0_col7" class="col_heading level0 col7" >Count_</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e78d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e78d_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_6e78d_row0_col1" class="data row0 col1" >47.381769</td>
#       <td id="T_6e78d_row0_col2" class="data row0 col2" >24.000000</td>
#       <td id="T_6e78d_row0_col3" class="data row0 col3" >159.851083</td>
#       <td id="T_6e78d_row0_col4" class="data row0 col4" >98.000000</td>
#       <td id="T_6e78d_row0_col5" class="data row0 col5" >3602.100565</td>
#       <td id="T_6e78d_row0_col6" class="data row0 col6" >1648.440000</td>
#       <td id="T_6e78d_row0_col7" class="data row0 col7" >2216</td>
#     </tr>
#     <tr>
#       <th id="T_6e78d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6e78d_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_6e78d_row1_col1" class="data row1 col1" >137.624881</td>
#       <td id="T_6e78d_row1_col2" class="data row1 col2" >99.000000</td>
#       <td id="T_6e78d_row1_col3" class="data row1 col3" >22.267398</td>
#       <td id="T_6e78d_row1_col4" class="data row1 col4" >19.000000</td>
#       <td id="T_6e78d_row1_col5" class="data row1 col5" >388.932741</td>
#       <td id="T_6e78d_row1_col6" class="data row1 col6" >305.950000</td>
#       <td id="T_6e78d_row1_col7" class="data row1 col7" >2098</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_60ea6_row0_col0 {
#   text-align: left;
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_60ea6_row0_col1, #T_60ea6_row0_col2, #T_60ea6_row0_col3, #T_60ea6_row1_col1, #T_60ea6_row1_col2, #T_60ea6_row1_col3 {
#   text-align: left;
# }
# #T_60ea6_row1_col0 {
#   text-align: left;
#   background-color: #ffff00;
#   color: #000000;
# }
# </style>
# <table id="T_60ea6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60ea6_level0_col0" class="col_heading level0 col0" >hierarchical|2Cluster</th>
#       <th id="T_60ea6_level0_col1" class="col_heading level0 col1" >Last_visited</th>
#       <th id="T_60ea6_level0_col2" class="col_heading level0 col2" >Purchase_frequency</th>
#       <th id="T_60ea6_level0_col3" class="col_heading level0 col3" >Money_spent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60ea6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_60ea6_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_60ea6_row0_col1" class="data row0 col1" >10 to 57 days ago</td>
#       <td id="T_60ea6_row0_col2" class="data row0 col2" >Bought 59 to 178 times</td>
#       <td id="T_60ea6_row0_col3" class="data row0 col3" >Spent around 967 to 3035 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_60ea6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_60ea6_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_60ea6_row1_col1" class="data row1 col1" >51 to 220 days ago</td>
#       <td id="T_60ea6_row1_col2" class="data row1 col2" >Bought 9 to 31 times</td>
#       <td id="T_60ea6_row1_col3" class="data row1 col3" >Spent around 174 to 485 Sterling</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Fitting hierarchical clustering with number of clusters based on dendogram distance threshold = 50
ahc = AgglomerativeClustering(n_clusters=3, linkage='ward')     # Initializing the model
y = ahc.fit_predict(X)                                                                

# Visualizing the clusters with n_clusters = 3
title = 'Agglomerative Clustering (threshold=45)'                                    
segment_name = 'hierarchical|3Cluster'
overlap_supress = 0.2
color="rainbow"
conclusion[segment_name] = plots_stats_summary(y, segment_name, color,title, overlap_supress)
# Out:
# Displaying the mean median and count of Recency, Frequency and Monetary for each group with the description:
# <style type="text/css">
# #T_91cc6_row0_col0, #T_91cc6_row0_col3, #T_91cc6_row0_col4, #T_91cc6_row0_col5, #T_91cc6_row0_col6, #T_91cc6_row2_col1, #T_91cc6_row2_col2, #T_91cc6_row2_col7 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_91cc6_row0_col1, #T_91cc6_row0_col2, #T_91cc6_row0_col7, #T_91cc6_row2_col0, #T_91cc6_row2_col3, #T_91cc6_row2_col4, #T_91cc6_row2_col5, #T_91cc6_row2_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_91cc6_row1_col0 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_91cc6_row1_col1 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_91cc6_row1_col2 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_91cc6_row1_col3 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_91cc6_row1_col4 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_91cc6_row1_col5 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_91cc6_row1_col6 {
#   background-color: #bde5b6;
#   color: #000000;
# }
# #T_91cc6_row1_col7 {
#   background-color: #5eb96b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_91cc6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91cc6_level0_col0" class="col_heading level0 col0" >hierarchical|3Cluster</th>
#       <th id="T_91cc6_level0_col1" class="col_heading level0 col1" >Recency_mean</th>
#       <th id="T_91cc6_level0_col2" class="col_heading level0 col2" >Recency_median</th>
#       <th id="T_91cc6_level0_col3" class="col_heading level0 col3" >Frequency_mean</th>
#       <th id="T_91cc6_level0_col4" class="col_heading level0 col4" >Frequency_median</th>
#       <th id="T_91cc6_level0_col5" class="col_heading level0 col5" >Monetary_mean</th>
#       <th id="T_91cc6_level0_col6" class="col_heading level0 col6" >Monetary_median</th>
#       <th id="T_91cc6_level0_col7" class="col_heading level0 col7" >Count_</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91cc6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_91cc6_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_91cc6_row0_col1" class="data row0 col1" >137.624881</td>
#       <td id="T_91cc6_row0_col2" class="data row0 col2" >99.000000</td>
#       <td id="T_91cc6_row0_col3" class="data row0 col3" >22.267398</td>
#       <td id="T_91cc6_row0_col4" class="data row0 col4" >19.000000</td>
#       <td id="T_91cc6_row0_col5" class="data row0 col5" >388.932741</td>
#       <td id="T_91cc6_row0_col6" class="data row0 col6" >305.950000</td>
#       <td id="T_91cc6_row0_col7" class="data row0 col7" >2098</td>
#     </tr>
#     <tr>
#       <th id="T_91cc6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_91cc6_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_91cc6_row1_col1" class="data row1 col1" >59.153535</td>
#       <td id="T_91cc6_row1_col2" class="data row1 col2" >29.000000</td>
#       <td id="T_91cc6_row1_col3" class="data row1 col3" >81.757576</td>
#       <td id="T_91cc6_row1_col4" class="data row1 col4" >72.000000</td>
#       <td id="T_91cc6_row1_col5" class="data row1 col5" >1672.551195</td>
#       <td id="T_91cc6_row1_col6" class="data row1 col6" >1220.480000</td>
#       <td id="T_91cc6_row1_col7" class="data row1 col7" >1485</td>
#     </tr>
#     <tr>
#       <th id="T_91cc6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_91cc6_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_91cc6_row2_col1" class="data row2 col1" >23.467852</td>
#       <td id="T_91cc6_row2_col2" class="data row2 col2" >17.000000</td>
#       <td id="T_91cc6_row2_col3" class="data row2 col3" >318.495212</td>
#       <td id="T_91cc6_row2_col4" class="data row2 col4" >224.000000</td>
#       <td id="T_91cc6_row2_col5" class="data row2 col5" >7521.910163</td>
#       <td id="T_91cc6_row2_col6" class="data row2 col6" >3514.180000</td>
#       <td id="T_91cc6_row2_col7" class="data row2 col7" >731</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6531b_row0_col0 {
#   text-align: left;
#   background-color: #8000ff;
#   color: #f1f1f1;
# }
# #T_6531b_row0_col1, #T_6531b_row0_col2, #T_6531b_row0_col3, #T_6531b_row1_col1, #T_6531b_row1_col2, #T_6531b_row1_col3, #T_6531b_row2_col1, #T_6531b_row2_col2, #T_6531b_row2_col3 {
#   text-align: left;
# }
# #T_6531b_row1_col0 {
#   text-align: left;
#   background-color: #80ffb4;
#   color: #000000;
# }
# #T_6531b_row2_col0 {
#   text-align: left;
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6531b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6531b_level0_col0" class="col_heading level0 col0" >hierarchical|3Cluster</th>
#       <th id="T_6531b_level0_col1" class="col_heading level0 col1" >Last_visited</th>
#       <th id="T_6531b_level0_col2" class="col_heading level0 col2" >Purchase_frequency</th>
#       <th id="T_6531b_level0_col3" class="col_heading level0 col3" >Money_spent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6531b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6531b_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_6531b_row0_col1" class="data row0 col1" >51 to 220 days ago</td>
#       <td id="T_6531b_row0_col2" class="data row0 col2" >Bought 9 to 31 times</td>
#       <td id="T_6531b_row0_col3" class="data row0 col3" >Spent around 174 to 485 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_6531b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6531b_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_6531b_row1_col1" class="data row1 col1" >12 to 74 days ago</td>
#       <td id="T_6531b_row1_col2" class="data row1 col2" >Bought 48 to 102 times</td>
#       <td id="T_6531b_row1_col3" class="data row1 col3" >Spent around 768 to 1766 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_6531b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6531b_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_6531b_row2_col1" class="data row2 col1" >4 to 33 days ago</td>
#       <td id="T_6531b_row2_col2" class="data row2 col2" >Bought 152 to 346 times</td>
#       <td id="T_6531b_row2_col3" class="data row2 col3" >Spent around 2370 to 5847 Sterling</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## E. DBSCAN Clustering

# %%
# Fitting DBSCAN clusterer
dbsc = DBSCAN(eps=0.2, min_samples=25)                                
y = dbsc.fit_predict(X)                                               

# Plotting Clusters for Visualization
title = 'DBSCAN Clustering'                                           
segment_name = 'DBSCAN'
overlap_supress = 0.2
color="YlGnBu"
conclusion[segment_name] = plots_stats_summary(y, segment_name, color,title, overlap_supress)
# Out:
# Displaying the mean median and count of Recency, Frequency and Monetary for each group with the description:
# <style type="text/css">
# #T_3bdc6_row0_col0, #T_3bdc6_row2_col1, #T_3bdc6_row2_col2, #T_3bdc6_row3_col3, #T_3bdc6_row3_col4, #T_3bdc6_row3_col5, #T_3bdc6_row3_col6, #T_3bdc6_row3_col7, #T_3bdc6_row4_col7 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_3bdc6_row0_col1 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_3bdc6_row0_col2, #T_3bdc6_row4_col5 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_3bdc6_row0_col3, #T_3bdc6_row0_col5, #T_3bdc6_row0_col7, #T_3bdc6_row2_col4, #T_3bdc6_row2_col6, #T_3bdc6_row3_col1, #T_3bdc6_row3_col2, #T_3bdc6_row4_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_3bdc6_row0_col4 {
#   background-color: #4eb264;
#   color: #f1f1f1;
# }
# #T_3bdc6_row0_col6 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_3bdc6_row1_col0 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_3bdc6_row1_col1 {
#   background-color: #58b668;
#   color: #f1f1f1;
# }
# #T_3bdc6_row1_col2 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_3bdc6_row1_col3 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_3bdc6_row1_col4 {
#   background-color: #b7e2b1;
#   color: #000000;
# }
# #T_3bdc6_row1_col5 {
#   background-color: #cbeac4;
#   color: #000000;
# }
# #T_3bdc6_row1_col6 {
#   background-color: #bce4b5;
#   color: #000000;
# }
# #T_3bdc6_row1_col7 {
#   background-color: #acdea6;
#   color: #000000;
# }
# #T_3bdc6_row2_col0 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_3bdc6_row2_col3 {
#   background-color: #268e47;
#   color: #f1f1f1;
# }
# #T_3bdc6_row2_col5 {
#   background-color: #4bb062;
#   color: #f1f1f1;
# }
# #T_3bdc6_row2_col7 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_3bdc6_row3_col0 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_3bdc6_row4_col1, #T_3bdc6_row4_col2 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_3bdc6_row4_col3 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_3bdc6_row4_col4 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_3bdc6_row4_col6 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# </style>
# <table id="T_3bdc6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3bdc6_level0_col0" class="col_heading level0 col0" >DBSCAN</th>
#       <th id="T_3bdc6_level0_col1" class="col_heading level0 col1" >Recency_mean</th>
#       <th id="T_3bdc6_level0_col2" class="col_heading level0 col2" >Recency_median</th>
#       <th id="T_3bdc6_level0_col3" class="col_heading level0 col3" >Frequency_mean</th>
#       <th id="T_3bdc6_level0_col4" class="col_heading level0 col4" >Frequency_median</th>
#       <th id="T_3bdc6_level0_col5" class="col_heading level0 col5" >Monetary_mean</th>
#       <th id="T_3bdc6_level0_col6" class="col_heading level0 col6" >Monetary_median</th>
#       <th id="T_3bdc6_level0_col7" class="col_heading level0 col7" >Count_</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3bdc6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3bdc6_row0_col0" class="data row0 col0" >-1</td>
#       <td id="T_3bdc6_row0_col1" class="data row0 col1" >79.632372</td>
#       <td id="T_3bdc6_row0_col2" class="data row0 col2" >36.000000</td>
#       <td id="T_3bdc6_row0_col3" class="data row0 col3" >112.891026</td>
#       <td id="T_3bdc6_row0_col4" class="data row0 col4" >53.000000</td>
#       <td id="T_3bdc6_row0_col5" class="data row0 col5" >2535.336654</td>
#       <td id="T_3bdc6_row0_col6" class="data row0 col6" >827.560000</td>
#       <td id="T_3bdc6_row0_col7" class="data row0 col7" >3120</td>
#     </tr>
#     <tr>
#       <th id="T_3bdc6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3bdc6_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_3bdc6_row1_col1" class="data row1 col1" >130.275959</td>
#       <td id="T_3bdc6_row1_col2" class="data row1 col2" >82.000000</td>
#       <td id="T_3bdc6_row1_col3" class="data row1 col3" >38.371375</td>
#       <td id="T_3bdc6_row1_col4" class="data row1 col4" >31.000000</td>
#       <td id="T_3bdc6_row1_col5" class="data row1 col5" >697.984510</td>
#       <td id="T_3bdc6_row1_col6" class="data row1 col6" >541.140000</td>
#       <td id="T_3bdc6_row1_col7" class="data row1 col7" >1069</td>
#     </tr>
#     <tr>
#       <th id="T_3bdc6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3bdc6_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_3bdc6_row2_col1" class="data row2 col1" >18.373494</td>
#       <td id="T_3bdc6_row2_col2" class="data row2 col2" >18.000000</td>
#       <td id="T_3bdc6_row2_col3" class="data row2 col3" >85.060241</td>
#       <td id="T_3bdc6_row2_col4" class="data row2 col4" >84.000000</td>
#       <td id="T_3bdc6_row2_col5" class="data row2 col5" >1574.467614</td>
#       <td id="T_3bdc6_row2_col6" class="data row2 col6" >1563.030000</td>
#       <td id="T_3bdc6_row2_col7" class="data row2 col7" >83</td>
#     </tr>
#     <tr>
#       <th id="T_3bdc6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3bdc6_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_3bdc6_row3_col1" class="data row3 col1" >214.666667</td>
#       <td id="T_3bdc6_row3_col2" class="data row3 col2" >209.000000</td>
#       <td id="T_3bdc6_row3_col3" class="data row3 col3" >8.055556</td>
#       <td id="T_3bdc6_row3_col4" class="data row3 col4" >8.000000</td>
#       <td id="T_3bdc6_row3_col5" class="data row3 col5" >131.291667</td>
#       <td id="T_3bdc6_row3_col6" class="data row3 col6" >130.040000</td>
#       <td id="T_3bdc6_row3_col7" class="data row3 col7" >18</td>
#     </tr>
#     <tr>
#       <th id="T_3bdc6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3bdc6_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_3bdc6_row4_col1" class="data row4 col1" >26.166667</td>
#       <td id="T_3bdc6_row4_col2" class="data row4 col2" >26.000000</td>
#       <td id="T_3bdc6_row4_col3" class="data row4 col3" >20.958333</td>
#       <td id="T_3bdc6_row4_col4" class="data row4 col4" >21.000000</td>
#       <td id="T_3bdc6_row4_col5" class="data row4 col5" >366.495000</td>
#       <td id="T_3bdc6_row4_col6" class="data row4 col6" >356.755000</td>
#       <td id="T_3bdc6_row4_col7" class="data row4 col7" >24</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_90d37_row0_col0 {
#   text-align: left;
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_90d37_row0_col1, #T_90d37_row0_col2, #T_90d37_row0_col3, #T_90d37_row1_col1, #T_90d37_row1_col2, #T_90d37_row1_col3, #T_90d37_row2_col1, #T_90d37_row2_col2, #T_90d37_row2_col3, #T_90d37_row3_col1, #T_90d37_row3_col2, #T_90d37_row3_col3, #T_90d37_row4_col1, #T_90d37_row4_col2, #T_90d37_row4_col3 {
#   text-align: left;
# }
# #T_90d37_row1_col0 {
#   text-align: left;
#   background-color: #c6e9b4;
#   color: #000000;
# }
# #T_90d37_row2_col0 {
#   text-align: left;
#   background-color: #40b5c4;
#   color: #f1f1f1;
# }
# #T_90d37_row3_col0 {
#   text-align: left;
#   background-color: #225da8;
#   color: #f1f1f1;
# }
# #T_90d37_row4_col0 {
#   text-align: left;
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_90d37">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90d37_level0_col0" class="col_heading level0 col0" >DBSCAN</th>
#       <th id="T_90d37_level0_col1" class="col_heading level0 col1" >Last_visited</th>
#       <th id="T_90d37_level0_col2" class="col_heading level0 col2" >Purchase_frequency</th>
#       <th id="T_90d37_level0_col3" class="col_heading level0 col3" >Money_spent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90d37_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90d37_row0_col0" class="data row0 col0" >-1</td>
#       <td id="T_90d37_row0_col1" class="data row0 col1" >14 to 115 days ago</td>
#       <td id="T_90d37_row0_col2" class="data row0 col2" >Bought 17 to 134 times</td>
#       <td id="T_90d37_row0_col3" class="data row0 col3" >Spent around 277 to 2255 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_90d37_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_90d37_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_90d37_row1_col1" class="data row1 col1" >57 to 201 days ago</td>
#       <td id="T_90d37_row1_col2" class="data row1 col2" >Bought 19 to 50 times</td>
#       <td id="T_90d37_row1_col3" class="data row1 col3" >Spent around 327 to 884 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_90d37_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_90d37_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_90d37_row2_col1" class="data row2 col1" >16 to 21 days ago</td>
#       <td id="T_90d37_row2_col2" class="data row2 col2" >Bought 75 to 95 times</td>
#       <td id="T_90d37_row2_col3" class="data row2 col3" >Spent around 1287 to 1753 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_90d37_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_90d37_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_90d37_row3_col1" class="data row3 col1" >193 to 231 days ago</td>
#       <td id="T_90d37_row3_col2" class="data row3 col2" >Bought 7 to 9 times</td>
#       <td id="T_90d37_row3_col3" class="data row3 col3" >Spent around 123 to 135 Sterling</td>
#     </tr>
#     <tr>
#       <th id="T_90d37_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_90d37_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_90d37_row4_col1" class="data row4 col1" >24 to 29 days ago</td>
#       <td id="T_90d37_row4_col2" class="data row4 col2" >Bought 19 to 22 times</td>
#       <td id="T_90d37_row4_col3" class="data row4 col3" >Spent around 320 to 405 Sterling</td>
#     </tr>
#   </tbody>
# </table>

# %%
summary = pd.DataFrame({"Clusterer": ['Binning','Quantile Cut', "K-Means", "K-Means", "K-Means", "Agglomerative","Agglomerative", "DBSCAN"],
                        'Criterion': ['RFM Score Binning', 'RFM Quantile Cut', 'Elbow Curve', 'Silhouette Score','Elbow Curve & Silhouette Score',
                                      'Dendogram (y=50)', 'Dendogram (y=45)', 'eps=0.2, min_samples=25'],
                        "Segments" : [4,4,5,2,4,2,3,4]},
                        index=['', '', '', '', '', '', '', ''])
summary.T
# Out:
#                                                                                \
# Clusterer            Binning      Quantile Cut      K-Means           K-Means
# Criterion  RFM Score Binning  RFM Quantile Cut  Elbow Curve  Silhouette Score
# Segments                   4                 4            5                 2
#
#                                                                                \
# Clusterer                         K-Means     Agglomerative     Agglomerative
# Criterion  Elbow Curve & Silhouette Score  Dendogram (y=50)  Dendogram (y=45)
# Segments                                4                 2                 3
#
#
# Clusterer                   DBSCAN
# Criterion  eps=0.2, min_samples=25
# Segments                         4

# %% [markdown]
# ## Conclusion

# %% [markdown]
# 1. Simple binning and Quantile based simple segmentation model for clustering is studied first
#
# 2. Analyzed data using complex clustering techniques like K-Means, Hierarchical and DBSCAN clusterer as well.
#
# 3. Though significantly seperated clusters are not visible in the plots, but these clusters are fairly valid as per the algorithms and statistics extracted by the formation of clusters
